# %%
# analise_problemas.ipynb

# Célula 1 - Imports e carregamento dos datasets
import pandas as pd
import numpy as np
import re
from pathlib import Path

# Define o diretório de dados (ajusta entre 'data' e 'datasets')
DATA_DIR = Path("data") if Path("data").exists() else Path("datasets")

# Carregamento explícito dos arquivos
clientes = pd.read_csv(DATA_DIR / "clientes.csv")
clientes_lab = pd.read_csv(DATA_DIR / "clientes_lab.csv")
produtos = pd.read_csv(DATA_DIR / "produtos.csv")
vendas = pd.read_csv(DATA_DIR / "vendas.csv")
logistica = pd.read_csv(DATA_DIR / "logistica.csv")

# Exibe o status do carregamento
print("Arquivos carregados:")
print(f" - clientes: {clientes.shape}")
print(f" - clientes_lab: {clientes_lab.shape}")
print(f" - produtos: {produtos.shape}")
print(f" - vendas: {vendas.shape}")
print(f" - logistica: {logistica.shape}")
# Out:
# Arquivos carregados:
#  - clientes: (16, 8)
#  - produtos: (20, 7)
#  - vendas: (25, 8)
#  - logistica: (22, 7)
